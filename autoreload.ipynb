# %%
# %matplotlib notebook

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import make_data
import matplotlib.pyplot as plt

x = make_data.get_x(200)
y = make_data.get_cos(x, 1, 2)

plt.plot(x, y);
# Out:
# <img src="data:image/png;base64,..." width="640">
